# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jackw\OneDrive\Documents\Data\Pandas\Creating Visualisations\Ice Cream Ratings.csv")
df = df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
# By default plot v= line plot

# %%
print(plt.style.available)
plt.style.use('_classic_test_patch')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line')
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'line', subplots = True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df.plot(kind = 'line', title = 'Ice Cream Ratings')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
df.plot(kind = 'line', title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind = 'bar', title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores')
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(kind = 'bar', title = 'Ice Cream Ratings', xlabel = 'Daily Ratings', ylabel = 'Scores', stacked = True)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Daily Ratings', ylabel='Scores'>

# %%
df['Flavor Rating'].plot(kind = 'bar', stacked = True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.barh(stacked = True)
# Out:
# <Axes: ylabel='Date'>

# %%
df.plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df.plot.scatter()
#
# TypeError: PlotAccessor.scatter() missing 2 required positional arguments: 'x' and 'y'

# %%
# Need to specify x and y axis for scatter plot

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# s = Size of plot

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 100)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', s = 500)
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
# c = Colour of plot

# %%
df.plot.scatter(x = 'Texture Rating', y = 'Overall Rating', c = 'Red')
# Out:
# <Axes: xlabel='Texture Rating', ylabel='Overall Rating'>

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.hist(bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize = (10,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.area(figsize = (4,2))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.pie()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.plot.pie()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1660, in PlotAccessor.pie(self, **kwargs)
#    1609 """
#    1610 Generate a pie plot.
#    1611
#    (...)
#    1653     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1654 """
#    1655 if (
#    1656     isinstance(self._parent, ABCDataFrame)
#    1657     and kwargs.get("y", None) is None
#    1658     and not kwargs.get("subplots", False)
#    1659 ):
# -> 1660     raise ValueError("pie requires either y column or 'subplots=True'")
#    1661 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
# Need to specify what column we are wroking with for pie charts

# %%
df.plot.pie(y= 'Flavor Rating')
# Out:
# <Axes: ylabel='Flavor Rating'>

# %%
df.plot.pie(y= 'Flavor Rating', figsize = (18,9))
# Out:
# <Axes: ylabel='Flavor Rating'>
