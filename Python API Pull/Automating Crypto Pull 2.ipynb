# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 

parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'e641fafc-d61c-4462-bd2d-c18a4945934c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'e641fafc-d61c-4462-bd2d-c18a4945934c',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


    df2 = pd.json_normalize(data['data'])
    df2['Timestamp'] = pd.to_datetime('now')
    df_append = pd.DataFrame(df2)
    df = pd.concat([df2,df_append])
    
    
    #df2 = pd.json_normalize(data['data'])
    #df2['Timestamp'] = pd.to_datetime('now')
    #df_append = pd.DataFrame(df2)
    #df = pd.concat([df2,df_append])
    
   # if not os.path.isfile(r'C:\Users\jackw\OneDrive\Documents\Data\Python\Python Scripts\Crypto API Pull Script\API.csv'): 
       # df.to_csv(r'C:\Users\jackw\OneDrive\Documents\Data\Python\Python Scripts\Crypto API Pull Script\API.csv', header='column_names')
   # else:
       # df.to_csv(r'C:\Users\jackw\OneDrive\Documents\Data\Python\Python Scripts\Crypto API Pull Script\API.csv', mode='a', header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\jackw\OneDrive\Documents\Data\Python\Python Scripts\Crypto API Pull Script\API.csv')
df72
# Out:
#      Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0             0      1      Bitcoin    BTC       bitcoin             10802
# 1             1   1027     Ethereum    ETH      ethereum              8346
# 2             2    825  Tether USDt   USDT        tether             73575
# 3             3   1839          BNB    BNB           bnb              2045
# 4             4   5426       Solana    SOL        solana               620
# 5             5     52          XRP    XRP           xrp              1219
# 6             6   3408         USDC   USDC      usd-coin             16464
# 7             7   2010      Cardano    ADA       cardano              1050
# 8             8   5805    Avalanche   AVAX     avalanche               653
# 9             9     74     Dogecoin   DOGE      dogecoin               886
# 10           10   1958         TRON    TRX          tron               921
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10802
# 1    1027     Ethereum    ETH      ethereum              8346
# 2     825  Tether USDt   USDT        tether             73582
# 3    1839          BNB    BNB           bnb              2045
# 4    5426       Solana    SOL        solana               620
# 5      52          XRP    XRP           xrp              1219
# 6    3408         USDC   USDC      usd-coin             16465
# 7    2010      Cardano    ADA       cardano              1050
# 8    5805    Avalanche   AVAX     avalanche               653
# 9      74     Dogecoin   DOGE      dogecoin               886
# 10   1958         TRON    TRX          tron               921
# 11   1975    Chainlink   LINK     chainlink              1601
# 12   6636     Polkadot    DOT  polkadot-new               679
# 13   3890      Polygon  MATIC       polygon              1263
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.03136                      -0.90604
# Ethereum                        -0.25832                       1.30968
# Tether USDt                      0.00299                      -0.02365
# BNB                             -0.09294                      -1.52640
# Solana                          -0.28192                      -1.72363
# XRP                              0.12123                      -3.81297
# USDC                             0.01386                       0.00577
# Cardano                         -0.32779                      -3.68101
# Avalanche                       -0.93138                      -2.83381
# Dogecoin                        -0.15876                      -1.64551
# TRON                             0.37909                       0.64807
# Chainlink                       -0.56449                       5.52111
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.03136
#              quote.USD.percent_change_24h    -0.90604
#              quote.USD.percent_change_7d      8.27053
#              quote.USD.percent_change_30d     1.63888
#              quote.USD.percent_change_60d    10.81487
#              quote.USD.percent_change_90d    22.16829
# Ethereum     quote.USD.percent_change_1h     -0.25832
#              quote.USD.percent_change_24h     1.30968
#              quote.USD.percent_change_7d      5.16403
#              quote.USD.percent_change_30d     2.57051
#              quote.USD.percent_change_60d    11.32807
#              quote.USD.percent_change_90d    27.04119
# Tether USDt  quote.USD.percent_change_1h      0.00299
#              quote.USD.percent_change_24h    -0.02365
#              quote.USD.percent_change_7d      0.03621
#              quote.USD.percent_change_30d    -0.04260
#              quote.USD.percent_change_60d    -0.03689
# ...

# %%
type(df3)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.03136
#             quote.USD.percent_change_24h  -0.90604
#             quote.USD.percent_change_7d    8.27053
#             quote.USD.percent_change_30d   1.63888
#             quote.USD.percent_change_60d  10.81487
#             quote.USD.percent_change_90d  22.16829
# Ethereum    quote.USD.percent_change_1h   -0.25832
#             quote.USD.percent_change_24h   1.30968
#             quote.USD.percent_change_7d    5.16403
#             quote.USD.percent_change_30d   2.57051
#             quote.USD.percent_change_60d  11.32807
#             quote.USD.percent_change_90d  27.04119
# Tether USDt quote.USD.percent_change_1h    0.00299
#             quote.USD.percent_change_24h  -0.02365
#             quote.USD.percent_change_7d    0.03621
#             quote.USD.percent_change_30d  -0.04260
#             quote.USD.percent_change_60d  -0.03689
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.03136
# 1       Bitcoin  quote.USD.percent_change_24h  -0.90604
# 2       Bitcoin   quote.USD.percent_change_7d   8.27053
# 3       Bitcoin  quote.USD.percent_change_30d   1.63888
# 4       Bitcoin  quote.USD.percent_change_60d  10.81487
# 5       Bitcoin  quote.USD.percent_change_90d  22.16829
# 6      Ethereum   quote.USD.percent_change_1h  -0.25832
# 7      Ethereum  quote.USD.percent_change_24h   1.30968
# 8      Ethereum   quote.USD.percent_change_7d   5.16403
# 9      Ethereum  quote.USD.percent_change_30d   2.57051
# 10     Ethereum  quote.USD.percent_change_60d  11.32807
# 11     Ethereum  quote.USD.percent_change_90d  27.04119
# 12  Tether USDt   quote.USD.percent_change_1h   0.00299
# 13  Tether USDt  quote.USD.percent_change_24h  -0.02365
# 14  Tether USDt   quote.USD.percent_change_7d   0.03621
# 15  Tether USDt  quote.USD.percent_change_30d  -0.04260
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.03136
# 1       Bitcoin  quote.USD.percent_change_24h  -0.90604
# 2       Bitcoin   quote.USD.percent_change_7d   8.27053
# 3       Bitcoin  quote.USD.percent_change_30d   1.63888
# 4       Bitcoin  quote.USD.percent_change_60d  10.81487
# 5       Bitcoin  quote.USD.percent_change_90d  22.16829
# 6      Ethereum   quote.USD.percent_change_1h  -0.25832
# 7      Ethereum  quote.USD.percent_change_24h   1.30968
# 8      Ethereum   quote.USD.percent_change_7d   5.16403
# 9      Ethereum  quote.USD.percent_change_30d   2.57051
# 10     Ethereum  quote.USD.percent_change_60d  11.32807
# 11     Ethereum  quote.USD.percent_change_90d  27.04119
# 12  Tether USDt   quote.USD.percent_change_1h   0.00299
# 13  Tether USDt  quote.USD.percent_change_24h  -0.02365
# 14  Tether USDt   quote.USD.percent_change_7d   0.03621
# 15  Tether USDt  quote.USD.percent_change_30d  -0.04260
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])

df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.03136
# 1       Bitcoin            24h  -0.90604
# 2       Bitcoin             7d   8.27053
# 3       Bitcoin            30d   1.63888
# 4       Bitcoin            60d  10.81487
# 5       Bitcoin            90d  22.16829
# 6      Ethereum             1h  -0.25832
# 7      Ethereum            24h   1.30968
# 8      Ethereum             7d   5.16403
# 9      Ethereum            30d   2.57051
# 10     Ethereum            60d  11.32807
# 11     Ethereum            90d  27.04119
# 12  Tether USDt             1h   0.00299
# 13  Tether USDt            24h  -0.02365
# 14  Tether USDt             7d   0.03621
# 15  Tether USDt            30d  -0.04260
# 16  Tether USDt            60d  -0.03689
# 17  Tether USDt            90d  -0.09438
# 18          BNB             1h  -0.09294
# 19          BNB            24h  -1.52640
# 20          BNB             7d   4.71418
# 21          BNB            30d  -0.73475
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
# Out:
# C:\Users\jackw\anaconda3\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\jackw\anaconda3\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Users\jackw\anaconda3\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df9 = df[['name', 'quote.USD.price', 'Timestamp']]
df9 = df9.query('name == "Bitcoin"')
df9
# Out:
#       name  quote.USD.price                  Timestamp
# 0  Bitcoin      42975.69143 2024-01-31 17:12:39.698319
# 0  Bitcoin      42975.69143 2024-01-31 17:12:39.698319

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='Timestamp', y='quote.USD.price', data = df9)
#API Runner needs to run for a while to show changes in price fluctuation
# Out:
# <Axes: xlabel='Timestamp', ylabel='quote.USD.price'>

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10802
# 1    1027     Ethereum    ETH      ethereum              8346
# 2     825  Tether USDt   USDT        tether             73582
# 3    1839          BNB    BNB           bnb              2045
# 4    5426       Solana    SOL        solana               620
# 5      52          XRP    XRP           xrp              1219
# 6    3408         USDC   USDC      usd-coin             16465
# 7    2010      Cardano    ADA       cardano              1050
# 8    5805    Avalanche   AVAX     avalanche               653
# 9      74     Dogecoin   DOGE      dogecoin               886
# 10   1958         TRON    TRX          tron               921
# 11   1975    Chainlink   LINK     chainlink              1601
# 12   6636     Polkadot    DOT  polkadot-new               679
# 13   3890      Polygon  MATIC       polygon              1263
# ...
